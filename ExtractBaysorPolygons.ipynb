# %% [markdown]
# ## Extract and combine polygon coordinates
# This notebook demonstrates how to...
# - extract polygons from baysor geojson file
# - convert polygons to coordinates i.e. each cell as multiple sets of coordinates for one polygon
# - merge all polygon coordinates for each cell
# - merge all polygon coordinates for each fov
# - merge all polygon coordinates for each run
#
# This output is used to generate gene cell matrix on todata1

# %%
options(warn = -1, verbose=FALSE)
#!/usr/bin/env Rscript 
library(dplyr)
library(httr)
library(readr)
library(patchwork)
library(unixtools)
library(ggrepel)
library(repr)
library(purrr)
library(pryr)
set_config(config(ssl_verifypeer = 0L))
ulimit::memory_limit(50000)
set.tempdir("/datastore/lucy/tmp/")
setwd("/datastore/lucy/CosMx")
# Out:
#  soft  hard
# 50000   Inf

# %%
#Load Korsunsky lab functions
source("./R/utils.R")
source("./R/TissueSegFunctions.R")
start_upR(TRUE)

# %%
#Path to directory where baysor segmentation output is stored
datadir<-c("/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose")

# %%
seg.libs <-list.files(datadir, pattern = "segmentation.csv", full.names = TRUE, recursive = TRUE)
seg.libs
# Out:
#  [1] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_297/segmentation.csv"
#  [2] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_298/segmentation.csv"
#  [3] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_299/segmentation.csv"
#  [4] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_300/segmentation.csv"
#  [5] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_301/segmentation.csv"
#  [6] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_302/segmentation.csv"
#  [7] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_49/segmentation.csv"
#  [8] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_50/segmentation.csv"
#  [9] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_51/segmentation.csv"
# [10] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_52/segmentation.csv"
# [11] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_53/segmentation.csv"
# [12] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_54/segmentation.csv"
# [13] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_55/segmentation.csv"
# [14] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_56/segmentation.csv"
# [15] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_57/segmentation.csv"
# [16] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_58/segmentation.csv"
# [17] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_59/segmentation.csv"
# [18] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_60/segmentation.csv"
# [19] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_61/segmentation.csv"
# [20] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_62/segmentation.csv"
# [21] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_63/segmentation.csv"
# [22] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_64/segmentation.csv"
# [23] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_65/segmentation.csv"
# [24] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_66/segmentation.csv"
# [25] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_67/segmentation.csv"
# [26] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_68/segmentation.csv"
# [27] "/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_69/segmentation.csv"

# %%
combine_fov_polygons <- function(fov){
    # load polygon file
    sf <- sf::st_read(paste0("/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_", fov,"/segmentation_polygons.json"))
    # extract polygons from geometry collection
    polyg <- st_collection_extract(sf, "POLYGON")
    # name cells by fov 
    polyg$cellID <- rownames(polyg)
    polyg$fov <- paste0("FOV", fov)
    polyg$cellID <- paste0(polyg$fov,"_",polyg$cellID)
    
    # convert multipolygons (shapes) to co-ordinates 
    polygon_coords <- list()
    for(cell in unique(polyg$cellID)){
        #Extract polygon for cell of interest
        multipolygon <- polyg[which(polyg$cellID==cell),c("geometry")]
        #Convert to coord matrix
        cell_polygon_st_coords <- as.data.frame(st_coordinates(multipolygon))
        #Keep only X and Y coordinates from dataframe
        cell_polygon_coords <- cell_polygon_st_coords[,c("X","Y")]
        #Add column with cell barcode
        cell_polygon_coords$cell <- cell
        #Stash in list element
        polygon_coords[[cell]] <- cell_polygon_coords  
    }
    
    # combine the polygons for each cell in fov 
    combined_fov_polygons <- do.call(rbind, polygon_coords)
        write.csv(combined_fov_polygons, paste0("/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_", fov,"/segmentation_polygons.csv"))
}

# %%
library(stringr)
for (dir in seg.libs){
    #get fov and number
    fov <- str_extract(dir, "fov_[0-9]+")
    # remove the "fov" part and just keep the number
    fov <- gsub("fov_", "", fov)
    print(paste("Processing FOV:", fov))
    # get stats file path from each
    combine_fov_polygons(fov)
}
# Out:
# [1] "Processing FOV: 297"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_297/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 47845.67 ymin: 90966.21 xmax: 52101.13 ymax: 95221.88
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 298"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_298/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 52101.57 ymin: 90966.43 xmax: 56357.11 ymax: 95181.23
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 299"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_299/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 43589.9 ymin: 86710.78 xmax: 47843.37 ymax: 90965.63
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 300"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_300/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 47845.36 ymin: 86710.26 xmax: 52101.11 ymax: 90965.78
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 301"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_301/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 43589.72 ymin: 82554.86 xmax: 47845 ymax: 86709.96
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 302"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_302/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 47845.41 ymin: 82454.24 xmax: 52101.17 ymax: 86709.91
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 49"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_49/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 10235.03 ymin: 91632.06 xmax: 14490.05 ymax: 95887.14
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 50"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_50/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 14490.85 ymin: 91631.71 xmax: 18424.58 ymax: 95330.17
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 51"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_51/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 1723.948 ymin: 87375.85 xmax: 5978.348 ymax: 91630.53
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 52"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_52/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 5979.229 ymin: 87378.83 xmax: 10234.03 ymax: 91630.79
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 53"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_53/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 10234.72 ymin: 87376.35 xmax: 14490.42 ymax: 91631.16
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 54"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_54/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 14490.82 ymin: 87375.94 xmax: 18724.63 ymax: 91631.14
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 55"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_55/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 1723.361 ymin: 83120.33 xmax: 5907.969 ymax: 87375.18
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 56"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_56/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 5982.449 ymin: 83177.27 xmax: 10234.42 ymax: 87374.2
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 57"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_57/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 10234.89 ymin: 83233.92 xmax: 14489.33 ymax: 87374.97
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 58"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_58/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 14490.94 ymin: 83219.14 xmax: 18546.82 ymax: 87375.21
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 59"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_59/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 68384.12 ymin: 91945.45 xmax: 72639.7 ymax: 96197.24
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 60"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_60/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 72640.1 ymin: 91945.24 xmax: 76895.68 ymax: 96200.86
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 61"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_61/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 72640.11 ymin: 87689.4 xmax: 76895.83 ymax: 91945.01
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 62"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_62/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 76896.06 ymin: 87689.35 xmax: 81151.76 ymax: 91944.97
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 63"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_63/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 86599.54 ymin: 90650.76 xmax: 90847.82 ymax: 94899.01
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 64"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_64/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 90848.13 ymin: 90650.68 xmax: 95103.68 ymax: 94905.83
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 65"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_65/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 95104.27 ymin: 90651.72 xmax: 99359.56 ymax: 94892.57
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 66"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_66/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 86592.43 ymin: 86395.12 xmax: 90847.56 ymax: 90650.27
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 67"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_67/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 90848.06 ymin: 86394.7 xmax: 95103.71 ymax: 90650.34
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 68"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_68/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 86697.8 ymin: 82146.07 xmax: 90847.56 ymax: 86394.25
# Geodetic CRS:  WGS 84
# [1] "Processing FOV: 69"
# Reading layer `segmentation_polygons' from data source
#   `/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_69/segmentation_polygons.json'
#   using driver `GeoJSON'
# Simple feature collection with 1 feature and 0 fields
# Geometry type: GEOMETRYCOLLECTION
# Dimension:     XY
# Bounding box:  xmin: 90848.21 ymin: 82139.69 xmax: 95103.78 ymax: 86394.24
# Geodetic CRS:  WGS 84

# %%
fov.list <- list()
for (dir in seg.libs){
    #get fov and number
    fov <- str_extract(dir, "fov_[0-9]+")
    # remove the "fov" part and just keep the number
    fov <- gsub("fov_", "", fov)
    fov.list[[fov]] <- fov
}
fov.list <- unlist(fov.list, use.names=FALSE)

# %%
fov.list
# Out:
#  [1] "297" "298" "299" "300" "301" "302" "49"  "50"  "51"  "52"  "53"  "54"
# [13] "55"  "56"  "57"  "58"  "59"  "60"  "61"  "62"  "63"  "64"  "65"  "66"
# [25] "67"  "68"  "69"

# %%
combine_all_polygons <- function(seg.libs){
# convert multipolygons (shapes) to co-ordinates 
    polygon_coords <- list()
    for(fov in fov.list){
        # Read in polygon .csv
        polygon_coords[[fov]] <- read.csv(paste0("/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/fov_", fov,"/segmentation_polygons.csv"))
    }
    # combine the polygons for each cell in fov 
    all_combined_polygons <- do.call(rbind, polygon_coords)
    all_combined_polygons <- all_combined_polygons %>% dplyr::select(X, Y, cell)
    write.csv(all_combined_polygons, paste0("/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/all_segmentation_polygons.csv"))
    
}

# %%
combine_all_polygons(seg.libs)

# %%
all_combined_polygons <- read.csv(paste0("/datastore/lucy/6KCosMxTMA/synovium_baysor_cellpose/all_segmentation_polygons.csv"))

# %%
head(all_combined_polygons)
# Out:
#   X.1   X        Y        cell
# 1 297.1 51010.72 91332.84 FOV297_1
# 2 297.2 51007.98 91336.41 FOV297_1
# 3 297.3 51024.90 91340.77 FOV297_1
# 4 297.4 51027.66 91339.87 FOV297_1
# 5 297.5 51038.25 91346.47 FOV297_1
# 6 297.6 51044.92 91349.17 FOV297_1
